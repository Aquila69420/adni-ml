# %%
import os
import pandas as pd

data_dir = 'data'

# %%
df = pd.read_csv(os.path.join(data_dir, 'ADNIMERGE_19Jun2025.csv'), low_memory=False)

# %% [markdown]
# https://adni.bitbucket.io/reference/adnimerge.html#examples
#
# https://adni.loni.usc.edu/wp-content/uploads/2012/08/slide_data_training_part2_reduced-size.pdf

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16421 entries, 0 to 16420
# Data columns (total 116 columns):
#  #    Column                    Dtype
# ---   ------                    -----
#  0    RID                       int64
#  1    COLPROT                   object
#  2    ORIGPROT                  object
#  3    PTID                      object
#  4    SITE                      int64
#  5    VISCODE                   object
#  6    EXAMDATE                  object
#  7    DX_bl                     object
#  8    AGE                       float64
#  9    PTGENDER                  object
#  10   PTEDUCAT                  int64
#  11   PTETHCAT                  object
#  12   PTRACCAT                  object
#  13   PTMARRY                   object
#  14   APOE4                     float64
#  15   FDG                       float64
#  16   PIB                       float64
#  17   AV45                      float64
#  18   FBB                       float64
# ...

# %%
df.describe()
# Out:
#                 RID          SITE           AGE      PTEDUCAT         APOE4  \
# count  16421.000000  16421.000000  16412.000000  16421.000000  16056.000000
# mean    2899.082273     81.733329     73.214173     16.105779      0.516193
# std     2220.442824    132.762777      7.028099      2.762672      0.646953
# min        2.000000      2.000000     50.400000      4.000000      0.000000
# 25%      751.000000     22.000000     68.500000     14.000000      0.000000
# 50%     2308.000000     41.000000     73.200000     16.000000      0.000000
# 75%     4707.000000    123.000000     78.100000     18.000000      1.000000
# max     7125.000000    941.000000     91.400000     20.000000      2.000000
#
#                FDG         PIB         AV45         FBB         CDRSB  ...  \
# count  3693.000000  223.000000  3080.000000  513.000000  11747.000000  ...
# mean      1.175624    1.783161     1.193030    1.175212      2.047927  ...
# ...

# %%
df.head()
# Out:
#    RID COLPROT ORIGPROT        PTID  SITE VISCODE    EXAMDATE DX_bl   AGE  \
# 0    2   ADNI1    ADNI1  011_S_0002    11      bl  2005-09-08    CN  74.3
# 1    3   ADNI1    ADNI1  011_S_0003    11      bl  2005-09-12    AD  81.3
# 2    3   ADNI1    ADNI1  011_S_0003    11     m06  2006-03-13    AD  81.3
# 3    3   ADNI1    ADNI1  011_S_0003    11     m12  2006-09-12    AD  81.3
# 4    3   ADNI1    ADNI1  011_S_0003    11     m24  2007-09-12    AD  81.3
#
#   PTGENDER  ...  PTAU_bl   FDG_bl PIB_bl AV45_bl  FBB_bl  Years_bl  Month_bl  \
# 0     Male  ...      NaN  1.33615    NaN     NaN     NaN  0.000000   0.00000
# 1     Male  ...    22.83  1.10860    NaN     NaN     NaN  0.000000   0.00000
# 2     Male  ...    22.83  1.10860    NaN     NaN     NaN  0.498289   5.96721
# 3     Male  ...    22.83  1.10860    NaN     NaN     NaN  0.999316  11.96720
# 4     Male  ...    22.83  1.10860    NaN     NaN     NaN  1.998630  23.93440
#
#    Month   M           update_stamp
# ...

# %%
csf_cols = ['ABETA', 'TAU', 'PTAU', 'ABETA_bl', 'TAU_bl', 'PTAU_bl']

# %%
huw_cols = ['PTGENDER', 'PTEDUCAT', 'AGE', 'DX', 'DX_bl', 'MMSE_bl', 'EcogPtTotal_bl', 'LDELTOTAL_BL', 'mPACCdigit_bl', 'mPACCtrailsB_bl', 'RAVLT_immediate_bl', 'RAVLT_learning_bl', 'RAVLT_forgetting_bl', 'RAVLT_perc_forgetting_bl']

# %%
parent_questionnaire_df = pd.read_csv(os.path.join(data_dir, 'FAMHXPAR_19Jun2025.csv'), low_memory=False)

# %%
parent_questionnaire_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10486 entries, 0 to 10485
# Data columns (total 219 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    RMT_PHASE                       object
#  1    ADNIOnlineID                    object
#  2    PTID                            object
#  3    RMT_Timepoint                   object
#  4    EXAMDATE                        object
#  5    SCREENER_SCORE                  int64
#  6    SCREENER_RECOMMEND              int64
#  7    QC_ATTEMPTS                     int64
#  8    QC_PASSED                       int64
#  9    USER_AGENT                      object
#  10   STORY1IMM_LANGUAGE              object
#  11   STORY1IMM_PLAYBACK_COUNT        float64
#  12   STORY1IMM_AUDIO_LENGTH          float64
#  13   STORY1IMM_NUM_PRONOUNS          float64
#  14   STORY1IMM_NUM_NOUNS             float64
#  15   STORY1IMM_NUM_PROPER_NOUNS      float64
# ...

# %%
parent_questionnaire_df.describe()
# Out:
#                 RID    MOTHALIVE      MOTHAGE      MOTHDEM      MOTHAD  \
# count   2245.000000  2215.000000  2147.000000  2209.000000  943.000000
# mean    7717.114477     0.168849    80.605030     0.488456    0.887593
# std     2087.973016     0.380682    13.327425     0.542553    0.600853
# min       21.000000     0.000000    17.000000     0.000000    0.000000
# 25%     6357.000000     0.000000    75.000000     0.000000    1.000000
# 50%     6849.000000     0.000000    84.000000     0.000000    1.000000
# 75%    10210.000000     0.000000    89.000000     1.000000    1.000000
# max    10854.000000     2.000000   105.000000     2.000000    2.000000
#
#         MOTHSXAGE    FATHALIVE      FATHAGE      FATHDEM      FATHAD  \
# count  927.000000  2210.000000  2110.000000  2196.000000  440.000000
# mean    76.248112     0.085973    75.346445     0.295082    0.813636
# std      9.379158     0.299135    14.517982     0.543668    0.623602
# ...

# %%
parent_questionnaire_df.head()
# Out:
#    PHASE        PTID   RID VISCODE VISCODE2     VISDATE  MOTHALIVE  MOTHAGE  \
# 0  ADNI3  027_S_6001  6001      sc       sc  2016-12-13        0.0     88.0
# 1  ADNI3  027_S_6002  6002      sc       sc  2017-01-03        0.0     49.0
# 2  ADNI3  024_S_6004  6004      sc       sc  2017-02-14        0.0     94.0
# 3  ADNI3  024_S_6005  6005      sc       sc  2017-02-22        0.0     94.0
# 4  ADNI3  037_S_1078  1078    init     m120  2017-02-22        NaN      NaN
#
#    MOTHDEM  MOTHAD  ...  FATHAD  FATHSXAGE    ID  SITEID    USERDATE  \
# 0      NaN     NaN  ...     NaN        NaN    95      20  2016-12-28
# 1      0.0     NaN  ...     NaN        NaN   223      20  2017-01-06
# 2      0.0     NaN  ...     1.0       80.0   685      19  2017-02-14
# 3      0.0     NaN  ...     1.0       84.0   975      19  2017-02-23
# 4      NaN     NaN  ...     NaN        NaN  1335      27  2017-03-10
#
#     USERDATE2  DD_CRF_VERSION_LABEL  LANGUAGE_CODE HAS_QC_ERROR  \
# ...

# %%
parent_questionnaire_cols = ['FHQMOM', 'FHQMOMAD', 'FHQDAD', 'FHQDADAD']

# %%
# Join the parent questionnaire data with the main dataframe based on the 'RID' column
net_df = df.merge(parent_questionnaire_df, on='RID', how='left')
net_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17463 entries, 0 to 17462
# Data columns (total 139 columns):
#  #    Column                    Dtype
# ---   ------                    -----
#  0    RID                       int64
#  1    COLPROT                   object
#  2    ORIGPROT                  object
#  3    PTID_x                    object
#  4    SITE                      int64
#  5    VISCODE_x                 object
#  6    EXAMDATE                  object
#  7    DX_bl                     object
#  8    AGE                       float64
#  9    PTGENDER                  object
#  10   PTEDUCAT                  int64
#  11   PTETHCAT                  object
#  12   PTRACCAT                  object
#  13   PTMARRY                   object
#  14   APOE4                     float64
#  15   FDG                       float64
#  16   PIB                       float64
#  17   AV45                      float64
#  18   FBB                       float64
# ...
